# %%
import pandas as pd
import numpy as np
import json
from pandas.api.types import CategoricalDtype

# %%
# Read all files
target_cols = ['RIF','INH', 'EMB', 'PZA', 'STR', 'CAP', 'AMI', 'CIP', 'KAN', 'LEVO', 'OFX', 'PAS', 'ETA']
db = pd.read_csv('/n/data1/hms/dbmi/farhat/Sanjana/MIC_data/MIC_rollingdb_cryptic.csv', nrows = 50, usecols = target_cols)
MIC = pd.read_csv('/n/data1/hms/dbmi/farhat/Sanjana/MIC_data/criticalConcentrations_updated.csv')

# %%
db
# Out:
#       AMI    EMB    ETA     INH     KAN    LEVO     RIF  STR  CIP  CAP  OFX  \
# 0   <=1.0   1.25    2.5     0.1     2.5    0.25  <=0.06  NaN  NaN  NaN  NaN
# 1   <=1.0   1.25   1.25  <=0.05     2.5    0.25  <=0.06  NaN  NaN  NaN  NaN
# 2   <=1.0    2.5    5.0     0.1     2.5     1.0    0.12  NaN  NaN  NaN  NaN
# 3   <=1.0   1.25   1.25  <=0.05  <=1.25    0.25    0.12  NaN  NaN  NaN  NaN
# 4   <=1.0    2.5   1.25     0.1     2.5     0.5    0.12  NaN  NaN  NaN  NaN
# 5   <=1.0    2.5    2.5  <=0.05     2.5    0.25  <=0.06  NaN  NaN  NaN  NaN
# 6   <=1.0   1.25   1.25  <=0.05  <=1.25    0.25  <=0.06  NaN  NaN  NaN  NaN
# 7   <=1.0    2.5    2.5  <=0.05  <=1.25    0.25  <=0.06  NaN  NaN  NaN  NaN
# 8   <=1.0   1.25    2.5  <=0.05  <=1.25    0.25  <=0.06  NaN  NaN  NaN  NaN
# 9   <=1.0    2.5   1.25     0.1     2.5    0.25  <=0.06  NaN  NaN  NaN  NaN
# 10  <=1.0    2.5   1.25     0.1     2.5     0.5  <=0.06  NaN  NaN  NaN  NaN
# ...

# %%
MIC
# Out:
#     Unnamed: 0                      antb  m7h10   m7h11    lj  mgit960  ABBR  \
# 0            0                  AMIKACIN    4.0     NaN  30.0     1.00   AMI
# 1            1               CAPREOMYCIN    4.0  10.000  40.0     2.50   CAP
# 2            2             CIPROFLOXACIN    NaN     NaN   NaN      NaN   CIP
# 3            3               CYCLOSERINE    NaN     NaN  30.0      NaN   CYS
# 4            4                ETHAMBUTOL    5.0   7.500   2.0     5.00   EMB
# 5            5               ETHIONAMIDE    5.0  10.000  40.0     5.00   ETA
# 6            6              GATIFLOXACIN    1.0     NaN   NaN      NaN  GATI
# 7            7                 ISONIAZID    0.2   0.200   0.2     0.10   INH
# 8            8                 KANAMYCIN    5.0   6.000  30.0     2.50   KAN
# 9            9              LEVOFLOXACIN    1.0     NaN   NaN     1.50  LEVO
# 10          10                 LINEZOLID    1.0     NaN   NaN      NaN   LIN
# ...

# %%
# Binarize the resistance

# %%
for i in db.columns:
    print(i)
# Out:
# ROLLINGDB_ID
# BIOSAMPLE_ACCESSION
# ID
# ISOLATION_LOCATION
# DB_OF_ORIGIN
# STUDY_NAME
# STUDY_PMID
# TESTING_LOCATION
# MEDIA
# AMI
# CLO
# EMB
# ETA
# INH
# KAN
# LEVO
# LIN
# MOXI
# RIF
# RFB
# DLM
# BDQ
# AMI_lower_bound
# AMI_midpoint
# AMI_upper_bound
# CLO_lower_bound
# CLO_midpoint
# CLO_upper_bound
# EMB_lower_bound
# EMB_midpoint
# EMB_upper_bound
# ETA_lower_bound
# ETA_midpoint
# ETA_upper_bound
# INH_lower_bound
# INH_midpoint
# INH_upper_bound
# KAN_lower_bound
# KAN_midpoint
# KAN_upper_bound
# LEVO_lower_bound
# LEVO_midpoint
# LEVO_upper_bound
# LIN_lower_bound
# LIN_midpoint
# LIN_upper_bound
# MOXI_lower_bound
# MOXI_midpoint
# MOXI_upper_bound
# RIF_lower_bound
# RIF_midpoint
# RIF_upper_bound
# RFB_lower_bound
# RFB_midpoint
# RFB_upper_bound
# DLM_lower_bound
# DLM_midpoint
# DLM_upper_bound
# BDQ_lower_bound
# BDQ_midpoint
# BDQ_upper_bound
# AMI_quality
# CLO_quality
# EMB_quality
# ETA_quality
# INH_quality
# KAN_quality
# LEVO_quality
# LIN_quality
# ...

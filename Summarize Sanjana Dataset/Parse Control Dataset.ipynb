# %%
import pandas as pd
import numpy as np
import json
from pandas.api.types import CategoricalDtype

# %%
# Read all files
target_cols = ['Isolate', 'RIFAMPICIN','ISONIAZID', 'ETHAMBUTOL', 'PYRAZINAMIDE', 'STREPTOMYCIN', 'CAPREOMYCIN', 'AMIKACIN', 'CIPROFLOXACIN', 'KANAMYCIN', 'LEVOFLOXACIN', 'OFLOXACIN', 'PARA-AMINOSALICYLIC_ACID', 'ETHIONAMIDE']
db = pd.read_csv('/n/data1/hms/dbmi/farhat/anna/focus_cnn/master_table_resistance.csv', usecols = target_cols)

# %%
db.to_csv('/home/kin672/gentb-summer22/Summarize Sanjana Dataset/resistance_data.csv')

# %%
db
# Out:
#           Isolate AMIKACIN CAPREOMYCIN CIPROFLOXACIN ETHAMBUTOL ETHIONAMIDE  \
# 0         00R0025        R           S           NaN          R           R
# 1         00R0086        R           R           NaN          R           R
# 2         00R0178        R           R           NaN          R           R
# 3         00R0223      NaN         NaN           NaN          S         NaN
# 4         00R0312      NaN           R           NaN          R         NaN
# ...           ...      ...         ...           ...        ...         ...
# 23046  ERS2401091        R         NaN           NaN          R         NaN
# 23047  ERS2401089        R         NaN           NaN          R         NaN
# 23048  ERS2401088        R         NaN           NaN          S         NaN
# 23049  ERS2401085        R         NaN           NaN          S         NaN
# 23050  ERS2401081        R         NaN           NaN          R         NaN
#
#       ISONIAZID KANAMYCIN LEVOFLOXACIN OFLOXACIN PARA-AMINOSALICYLIC_ACID  \
# 0             R         R          NaN         S                      NaN
# 1             R         R          NaN         S                      NaN
# 2             R         R          NaN         R                      NaN
# 3             S         S          NaN       NaN                      NaN
# 4             R         R          NaN       NaN                      NaN
# ...         ...       ...          ...       ...                      ...
# 23046         R       NaN          NaN       NaN                        S
# 23047         R       NaN          NaN       NaN                        S
# 23048         R       NaN          NaN       NaN                      NaN
# 23049         R       NaN          NaN       NaN                        S
# 23050         R       NaN          NaN       NaN                        S
#
#       PYRAZINAMIDE RIFAMPICIN STREPTOMYCIN
# 0                S          R            R
# 1                R          R            R
# 2                R          R            R
# 3              NaN          S            S
# 4              NaN          R            R
# ...            ...        ...          ...
# 23046            S          R            R
# 23047            S          R            R
# 23048            S          R            R
# 23049            R          R            R
# 23050            S          R            R
#
# [23051 rows x 14 columns]

# %%
MIC
# Out:
#     Unnamed: 0                      antb  m7h10   m7h11    lj  mgit960  ABBR  \
# 0            0                  AMIKACIN    4.0     NaN  30.0     1.00   AMI
# 1            1               CAPREOMYCIN    4.0  10.000  40.0     2.50   CAP
# 2            2             CIPROFLOXACIN    NaN     NaN   NaN      NaN   CIP
# 3            3               CYCLOSERINE    NaN     NaN  30.0      NaN   CYS
# 4            4                ETHAMBUTOL    5.0   7.500   2.0     5.00   EMB
# 5            5               ETHIONAMIDE    5.0  10.000  40.0     5.00   ETA
# 6            6              GATIFLOXACIN    1.0     NaN   NaN      NaN  GATI
# 7            7                 ISONIAZID    0.2   0.200   0.2     0.10   INH
# 8            8                 KANAMYCIN    5.0   6.000  30.0     2.50   KAN
# 9            9              LEVOFLOXACIN    1.0     NaN   NaN     1.50  LEVO
# 10          10                 LINEZOLID    1.0     NaN   NaN      NaN   LIN
# 11          11              MOXIFLOXACIN    0.5   0.500   1.0     0.25  MOXI
# 12          12                 OFLOXACIN    2.0   2.000   4.0     2.00   OFX
# 13          13  PARA-AMINOSALICYLIC_ACID    2.0   8.000   1.0     4.00   PAS
# 14          14             PROTHIONAMIDE    NaN     NaN  40.0     2.50   PRO
# 15          15              PYRAZINAMIDE    NaN     NaN   NaN   100.00   PZA
# 16          16                 RIFABUTIN    0.5   0.500   NaN     0.50   RFB
# 17          17                RIFAMPICIN    0.5   0.500  40.0     1.00   RIF
# 18          18              STREPTOMYCIN    2.0   2.000   4.0     1.00   STR
# 19          19               CLOFAZIMINE    1.0     NaN   NaN      NaN   CLO
# 20          20               BEDAQUILINE    NaN   0.250   NaN     1.60   BDQ
# 21          21                 DELAMANID    NaN   0.016   NaN      NaN   DLM
#
#     UKMYC
# 0    1.00
# 1     NaN
# 2     NaN
# 3     NaN
# 4    4.00
# 5    4.00
# 6     NaN
# 7    0.10
# 8    4.00
# 9    1.00
# 10   1.00
# 11   1.00
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16   0.12
# 17   0.50
# 18    NaN
# 19   0.25
# 20   0.25
# 21   0.12

# %%
# Binarize the resistance

# %%
for i in db.columns:
    print(i)
# Out:
# ROLLINGDB_ID
# BIOSAMPLE_ACCESSION
# ID
# ISOLATION_LOCATION
# DB_OF_ORIGIN
# STUDY_NAME
# STUDY_PMID
# TESTING_LOCATION
# MEDIA
# AMI
# CLO
# EMB
# ETA
# INH
# KAN
# LEVO
# LIN
# MOXI
# RIF
# RFB
# DLM
# BDQ
# AMI_lower_bound
# AMI_midpoint
# AMI_upper_bound
# CLO_lower_bound
# CLO_midpoint
# CLO_upper_bound
# EMB_lower_bound
# EMB_midpoint
# EMB_upper_bound
# ETA_lower_bound
# ETA_midpoint
# ETA_upper_bound
# INH_lower_bound
# INH_midpoint
# INH_upper_bound
# KAN_lower_bound
# KAN_midpoint
# KAN_upper_bound
# LEVO_lower_bound
# LEVO_midpoint
# LEVO_upper_bound
# LIN_lower_bound
# LIN_midpoint
# LIN_upper_bound
# MOXI_lower_bound
# MOXI_midpoint
# MOXI_upper_bound
# RIF_lower_bound
# RIF_midpoint
# RIF_upper_bound
# RFB_lower_bound
# RFB_midpoint
# RFB_upper_bound
# DLM_lower_bound
# DLM_midpoint
# DLM_upper_bound
# BDQ_lower_bound
# BDQ_midpoint
# BDQ_upper_bound
# AMI_quality
# CLO_quality
# EMB_quality
# ETA_quality
# INH_quality
# KAN_quality
# LEVO_quality
# LIN_quality
# MOXI_quality
# RIF_quality
# RFB_quality
# BDQ_quality
# STR
# CIP
# CYS
# CAP
# OFX
# PAS
# PZA
# PRO
# CLAR
# GATI
# AMOXCLAV
# STR_lower_bound
# STR_upper_bound
# STR_midpoint
# CIP_lower_bound
# CIP_upper_bound
# CIP_midpoint
# CYS_lower_bound
# CYS_upper_bound
# CYS_midpoint
# CAP_lower_bound
# CAP_upper_bound
# CAP_midpoint
# OFX_lower_bound
# OFX_upper_bound
# OFX_midpoint
# PAS_lower_bound
# PAS_upper_bound
# PAS_midpoint
# PZA_lower_bound
# PZA_upper_bound
# PZA_midpoint
# PRO_lower_bound
# PRO_upper_bound
# PRO_midpoint
# CLAR_lower_bound
# CLAR_upper_bound
# CLAR_midpoint
# GATI_lower_bound
# GATI_upper_bound
# GATI_midpoint
# AMOXCLAV_lower_bound
# AMOXCLAV_upper_bound
# AMOXCLAV_midpoint

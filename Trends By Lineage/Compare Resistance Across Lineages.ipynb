# %%
import pandas as pd
import numpy as np
import json
import glob, os, subprocess
import scipy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/home/kin672/gentb-summer22/submission_data_by_primary_lin_7-24.csv')
drugs = df.Drug.unique()

# %%
df
# Out:
#     Drug Primary Lineage Family  Number of Resistant Strains  \
# 0    amk                      1                            5
# 1    amk                      2                          294
# 2    amk                      3                           30
# 3    amk                      4                          182
# 4    amk                      5                            0
# ..   ...                    ...                          ...
# 112  str                      5                            0
# 113  str                      6                            0
# 114  str                 Bovine                            0
# 115  str               Multiple                           48
# 116  str                   None                            0
#
#      Number of Susceptible Strains  Total Isolates  Proportion Resistant
# 0                              386             391              0.012788
# 1                             3257            3551              0.082794
# ...

# %%
sns.catplot(data = df.loc[[i in ['1','2','3','4','5','6'] for i in df['Primary Lineage Family']],:], x = 'Drug', y = 'Proportion Resistant', hue = 'Primary Lineage Family', kind = 'bar')

# %%
plt.savefig('Proportion Resistant For Each Drug and Lineage.png')

# %%
[i in ['1','2','3','4','5','6'] for i in df['Primary Lineage Family']]
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
# ...

# %%
# Out:
#   Input In [33]
#     [1:6]
#       ^
# SyntaxError: invalid syntax

# %%
# for drug in drugs:
drug = 'amk'

temp = df.loc[df.Drug == drug, :]

# %%
temp
# Out:
#   Drug Primary Lineage Family  Number of Resistant Strains  \
# 0  amk                      1                            5
# 1  amk                      2                          294
# 2  amk                      3                           30
# 3  amk                      4                          182
# 4  amk                      5                            0
# 5  amk                      6                            0
# 6  amk                 Bovine                            0
# 7  amk               Multiple                            6
# 8  amk                   None                            0
#
#    Number of Susceptible Strains  Total Isolates  Proportion Resistant
# 0                            386             391              0.012788
# 1                           3257            3551              0.082794
# 2                            325             355              0.084507
# 3                           3490            3672              0.049564
# ...

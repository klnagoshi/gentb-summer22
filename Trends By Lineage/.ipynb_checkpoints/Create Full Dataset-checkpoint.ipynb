# %%
import pandas as pd
import numpy as np
import json
import glob, os, subprocess
import matplotlib.pyplot as plt

summarized_df = pd.read_csv('/home/kin672/gentb-summer22/Creating Summaries from Relevant Files/7-18 Output/summarized_full_7-18.csv', usecols = [1, 2, 3, 4, 5])

# %%
summarized_df['Total Isolates'] = summarized_df['Number of Resistant Strains'] + summarized_df['Number of Susceptible Strains']

# %%
summarized_df
# Out:
#      Drug     Lineage  Percentage of Strains that are Resistant  \
# 0     amk           1                                       0.0
# 1     amk         1.1                                       0.0
# 2     amk       1.1.1                                       0.0
# 3     amk   1.1.1,4.9                                       0.0
# 4     amk     1.1.1.1                                       0.0
# ...   ...         ...                                       ...
# 2218  str           5                                       0.0
# 2219  str           6                                       0.0
# 2220  str  6,BOV_AFRI                                       0.0
# 2221  str    BOV_AFRI                                       0.0
# 2222  str         NaN                                       0.0
#
#       Number of Resistant Strains  Number of Susceptible Strains  \
# 0                               0                              1
# 1                               0                              1
# 2                               0                              3
# 3                               0                              1
# 4                               0                              3
# ...                           ...                            ...
# 2218                            0                              1
# 2219                            0                              1
# 2220                            0                              4
# 2221                            0                             20
# 2222                            0                              8
#
#       Total Isolates
# 0                  1
# 1                  1
# 2                  3
# 3                  1
# 4                  3
# ...              ...
# 2218               1
# 2219               1
# 2220               4
# 2221              20
# 2222               8
#
# [2223 rows x 6 columns]

# %%
# All of the individual lineages
all_lineages = summarized_df.loc[:, 'Lineage'].str.split(',', expand=True)
all_lineages = all_lineages.rename(columns = {0: 'Lineage 1', 1: 'Lineage 2', 2: 'Lineage 3', 3:'Lineage 4', 4:'Lineage 5', 5:'Lineage 6', 6:'Lineage 7', 7:'Lineage 8', 8:'Lineage 9'})
all_lineages
# Out:
#      Lineage 1 Lineage 2 Lineage 3 Lineage 4 Lineage 5 Lineage 6 Lineage 7  \
# 0            1      None      None      None      None      None      None
# 1          1.1      None      None      None      None      None      None
# 2        1.1.1      None      None      None      None      None      None
# 3        1.1.1       4.9      None      None      None      None      None
# 4      1.1.1.1      None      None      None      None      None      None
# ...        ...       ...       ...       ...       ...       ...       ...
# 2218         5      None      None      None      None      None      None
# 2219         6      None      None      None      None      None      None
# 2220         6  BOV_AFRI      None      None      None      None      None
# 2221  BOV_AFRI      None      None      None      None      None      None
# 2222       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#      Lineage 8 Lineage 9
# 0         None      None
# 1         None      None
# 2         None      None
# 3         None      None
# 4         None      None
# ...        ...       ...
# 2218      None      None
# 2219      None      None
# 2220      None      None
# 2221      None      None
# 2222       NaN       NaN
#
# [2223 rows x 9 columns]

# %%
# Get the number of lineages
summarized_df['Number_of_Lineages'] = pd.Series()
for index, row in all_lineages.iterrows():
    summarized_df.at[index, 'Number_of_Lineages'] = len(row.unique()) - 1
summarized_df
# Out:
# /tmp/ipykernel_32637/3575801309.py:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   summarized_df['Number_of_Lineages'] = pd.Series()
#      Drug     Lineage  Percentage of Strains that are Resistant  \
# 0     amk           1                                       0.0
# 1     amk         1.1                                       0.0
# 2     amk       1.1.1                                       0.0
# 3     amk   1.1.1,4.9                                       0.0
# 4     amk     1.1.1.1                                       0.0
# ...   ...         ...                                       ...
# 2218  str           5                                       0.0
# 2219  str           6                                       0.0
# 2220  str  6,BOV_AFRI                                       0.0
# 2221  str    BOV_AFRI                                       0.0
# 2222  str         NaN                                       0.0
#
#       Number of Resistant Strains  Number of Susceptible Strains  \
# 0                               0                              1
# 1                               0                              1
# 2                               0                              3
# 3                               0                              1
# 4                               0                              3
# ...                           ...                            ...
# 2218                            0                              1
# 2219                            0                              1
# 2220                            0                              4
# 2221                            0                             20
# 2222                            0                              8
#
#       Total Isolates  Number_of_Lineages
# 0                  1                 1.0
# 1                  1                 1.0
# 2                  3                 1.0
# 3                  1                 2.0
# 4                  3                 1.0
# ...              ...                 ...
# 2218               1                 1.0
# 2219               1                 1.0
# 2220               4                 2.0
# 2221              20                 1.0
# 2222               8                 0.0
#
# [2223 rows x 7 columns]

# %%
# Get the primary lineage family
summarized_df['Primary Lineage Family'] = 'Multiple or None'
summarized_df['Primary Lineage Family'] = [long[0:1] for long in summarized_df.Lineage if summarized_df.Number_of_Lineages == 1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [42], in <cell line: 3>()
#       1 # Get the primary lineage family
#       2 summarized_df['Primary Lineage Family'] = 'Multiple or None'
# ----> 3 summarized_df['Primary Lineage Family'] = [long[0:1] for long in summarized_df.Lineage if summarized_df.Number_of_Lineages == 1]
#
# Input In [42], in <listcomp>(.0)
#       1 # Get the primary lineage family
#       2 summarized_df['Primary Lineage Family'] = 'Multiple or None'
# ----> 3 summarized_df['Primary Lineage Family'] = [long[0:1] for long in summarized_df.Lineage if summarized_df.Number_of_Lineages == 1]
#
# File ~/anaconda3/envs/jupytervenv/lib/python3.10/site-packages/pandas/core/generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Out:
#      Lineage 1 Lineage 2 Lineage 3 Lineage 4 Lineage 5 Lineage 6 Lineage 7  \
# 0            1      None      None      None      None      None      None
# 1          1.1      None      None      None      None      None      None
# 2        1.1.1      None      None      None      None      None      None
# 3        1.1.1       4.9      None      None      None      None      None
# 4      1.1.1.1      None      None      None      None      None      None
# ...        ...       ...       ...       ...       ...       ...       ...
# 2218         5      None      None      None      None      None      None
# 2219         6      None      None      None      None      None      None
# 2220         6  BOV_AFRI      None      None      None      None      None
# 2221  BOV_AFRI      None      None      None      None      None      None
# 2222       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#      Lineage 8 Lineage 9
# 0         None      None
# 1         None      None
# 2         None      None
# 3         None      None
# 4         None      None
# ...        ...       ...
# 2218      None      None
# 2219      None      None
# 2220      None      None
# 2221      None      None
# 2222       NaN       NaN
#
# [2223 rows x 9 columns]

# %%
import numpy as np
import pandas as pd
import json

# %%
with open('//home//kin672//Kira_GenTB//Isolating Relevant Files//strainIDs_with_errors.json') as f1:
    bad_IDs_old = json.load(f1)
    
with open('//home//kin672//Kira_GenTB//Isolating Relevant Files//strainIDs_with_errors-new_IDs.json') as f2:
    bad_IDs_new = json.load(f2)
    
with open('//home//kin672//Kira_GenTB//Isolating Relevant Files//relevant_file_names-new_IDs.json') as f3:
    relevant_new = json.load(f3)
    
with open('//home//kin672//Kira_GenTB//Isolating Relevant Files//relevant_file_names.json') as f4:
    relevant_old = json.load(f4)

# %%
print(len(relevant_new))
print(len(relevant_old))
# Out:
# 8110
# 6742

# %%
bad_IDs.get('More than one lineage file')
# Out:
# {'tbdata_00001004': ['Serialsamples'],
#  'tbdata_00001059': ['1773'],
#  'tbdata_00001242': ['1773'],
#  'tbdata_00001112': ['1773'],
#  'tbdata_00001204': ['1773'],
#  'tbdata_00001056': ['1773'],
#  'tbdata_00001182': ['rename_mycobacterium_tuberculosis_m13'],
#  'tbdata_00001188': ['rename_mycobacterium_tuberculosis_m13'],
#  'tbdata_00001207': ['1773'],
#  'tbdata_00001002': ['1733'],
#  'tbdata_00001025': ['1773'],
#  'tbdata_00001081': ['1773'],
#  'tbdata_00001113': ['1773'],
#  'tbdata_00001003': ['1733'],
#  'tbdata_00001057': ['1773'],
#  'tbdata_00001082': ['1773'],
#  'tbdata_00001115': ['1773'],
#  'tbdata_00001024': ['1773'],
#  'tbdata_00000984': ['BORA_1'],
#  'tbdata_00001183': ['rename_mycobacterium_tuberculosis_m13'],
#  'tbdata_00001058': ['1773'],
#  'tbdata_00000628': ['BORA_34', 'BORA_36'],
#  'tbdata_00001000': ['1733', '1773'],
#  'tbdata_00000624': ['BORA_2', 'BORA_10'],
#  'tbdata_00000998': ['1733'],
#  'tbdata_00001001': ['1733', '1773'],
# ...

# %%
bad_IDs.get('No lineage files')
# Out:
# {'tbdata_00001049': ['70'],
#  'tbdata_00000360': ['1479150601544T896015lib5742nextseqn0051151bp',
#   '02R1753'],
#  'tbdata_00000354': ['01R0774',
#   '1479144813357T182015lib5025nextseqn0035151bp',
#   'SAMN03649060'],
#  'tbdata_00001168': ['matrix'],
#  'tbdata_00000776': ['matrix'],
#  'tbdata_00001039': ['X1081_ano_flt'],
#  'tbdata_00000359': ['SAMEA2533548'],
#  'tbdata_00000944': ['TB-111-15090-18_S77_R',
#   'TB-111-15776-18_S100_R',
#   'TB-111-135-19-138_S56_R',
#   'TB-111-15345-19_S9_R',
#   'TB-111-161-19-18-138_S33_R',
#   'TB-111-15526-18-138_S70_R',
#   'TB-111-15919-18_S131_R',
#   'TB-111-15916-19_S161_R'],
#  'tbdata_00001368': ['Test1113'],
#  'tbdata_00000580': ['TSVC_variants_IonXpress_001'],
#  'tbdata_00000697': ['POR115S'],
#  'tbdata_00000967': ['Iso1'],
#  'tbdata_00000947': ['TB-111-16436-19_S115_R',
#   'TB-333-2151-19_S90_R',
#   'TB-333-1701-19_S92_R',
#   'TB-111-16224-19_S68_R'],
#  'tbdata_00001038': ['X552_ano_flt',
#   'X564_ano_flt',
# ...

# %%
bad_IDs.get('The strainID already existed')
# Out:
# {'tbdata_00000880': ['SRR2101131', 'SRR1011507', 'SRR5341216'],
#  'tbdata_00001179': ['IonXpress_016_2020_07_14_sample no 2427'],
#  'tbdata_00000709': ['Peru4912'],
#  'tbdata_00001403': ['Serialsamples'],
#  'tbdata_00001247': ['var'],
#  'tbdata_00000894': ['SRR2101131', 'SRR1011507', 'SRR5341216'],
#  'tbdata_00001408': ['Serialsamples'],
#  'tbdata_00000708': ['ERR1873539', 'Peru4912'],
#  'tbdata_00000783': ['ERR1873539'],
#  'tbdata_00000932': ['Sample No 3213167'],
#  'tbdata_00000662': ['Peru4912'],
#  'tbdata_00000895': ['SRR2101131', 'SRR1011507', 'SRR5341216'],
#  'tbdata_00001385': ['Serialsamples'],
#  'tbdata_00001406': ['Serialsamples'],
#  'tbdata_00001211': ['IonXpress_001_2020_10_11_sample no 2111'],
#  'tbdata_00001204': ['1408971'],
#  'tbdata_00000759': ['ERR1873539_cut'],
#  'tbdata_00000753': ['Peru4912'],
#  'tbdata_00000673': ['ERR257932', 'ERR257899'],
#  'tbdata_00000755': ['Peru4912'],
#  'tbdata_00001056': ['1438879',
#   '1438836',
#   '1408937',
# ...
